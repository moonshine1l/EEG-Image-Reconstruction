# %% [markdown]
# # Daytime Hypotesis for fft

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from scipy import stats


def analyze_fft_structure(loaded):
    """Анализирует структуру FFT данных для exec/rest периодов"""
    power_example = loaded['power_0']
    
    print(f"Shape of power data: {power_example.shape}")
    print(f"Number of dimensions: {power_example.ndim}")
    
    if power_example.ndim == 2:
        if power_example.shape[0] == 64 or power_example.shape[0] == 63:
            n_channels = power_example.shape[0]
            n_freq_bins = power_example.shape[1]
            data_structure = "(channels, frequencies)"
        else:
            n_channels = 1
            n_freq_bins = power_example.shape[1]
            data_structure = "(time, frequencies) - single channel"
    
    elif power_example.ndim == 3:
        n_channels = power_example.shape[0]
        n_time_points = power_example.shape[1]
        n_freq_bins = power_example.shape[2]
        data_structure = "(channels, time, frequencies)"
    
    else:
        raise ValueError(f"Unexpected data dimension: {power_example.ndim}")
    
    print(f"Data structure: {data_structure}")
    print(f"Number of channels: {n_channels}")
    print(f"Number of frequency bins: {n_freq_bins}")
    
    freqs = np.linspace(0, 100, n_freq_bins)
    
    return freqs, n_channels, n_freq_bins

def process_excel_time(file_path, column_index=19):
    """Обрабатывает временные категории из Excel файла"""
    df = pd.read_excel(file_path, header=1)
    time_data = df.iloc[:, column_index]
    
    time_category = []
    for cell in time_data:
        if pd.isna(cell):
            time_category.append(None)
        else:
            try:
                if isinstance(cell, str):
                    try:
                        dt = datetime.strptime(cell, "%d.%m.%Y %H:%M")
                    except ValueError:
                        dt = datetime.strptime(cell, "%Y-%m-%d %H:%M:%S")
                else:
                    dt = cell if hasattr(cell, 'hour') else pd.to_datetime(cell)
                
                time_category.append("day" if dt.hour < 18 else "evening")
            except Exception as e:
                print(f"Ошибка обработки ячейки {cell}: {e}")
                time_category.append(None)
    
    return time_category

def extract_exec_rest_periods(power_data, data_dims):
    """Корректно извлекает exec и rest периоды с учетом структуры данных"""
    
    if data_dims == '3d':
        # 3D данные: (каналы, время, частоты)
        n_time_points = power_data.shape[1]
        
        if n_time_points >= 6:
            rest1_end = n_time_points // 3
            exec_end = 2 * n_time_points // 3
            
            periods = {
                'rest1': slice(0, rest1_end),
                'exec': slice(rest1_end, exec_end),
                'rest2': slice(exec_end, n_time_points),
                'full': slice(0, n_time_points)
            }
        else:
            periods = {'full': slice(0, n_time_points)}
    
    elif data_dims == '2d_temporal':
        # 2D временные данные: (время, частоты)
        n_time_points = power_data.shape[0]
        
        if n_time_points >= 6:
            rest1_end = n_time_points // 3
            exec_end = 2 * n_time_points // 3
            
            periods = {
                'rest1': slice(0, rest1_end),
                'exec': slice(rest1_end, exec_end),
                'rest2': slice(exec_end, n_time_points),
                'full': slice(0, n_time_points)
            }
        else:
            periods = {'full': slice(0, n_time_points)}
    
    elif data_dims == '2d_spectral':
        # 2D спектральные данные: (каналы, частоты) - нет временной динамики
        periods = {'full': slice(0, power_data.shape[1])}
    
    else:
        raise ValueError(f"Unsupported data dimensions: {data_dims}")
    
    print(f"  Extracted periods: {list(periods.keys())}")
    return periods

def process_power_data(power_data, periods, channel, band_mask, data_dims):
    """Обрабатывает данные мощности для заданного периода и канала"""
    
    band_powers = {}
    
    for period_name, period_slice in periods.items():
        try:
            if data_dims == '3d':
                # (channels, time, frequencies)
                time_data = power_data[channel, period_slice, :]
                band_power = np.mean(time_data[:, band_mask])
                
            elif data_dims == '2d_temporal':
                # (time, frequencies) 
                time_data = power_data[period_slice, :]
                band_power = np.mean(time_data[:, band_mask])
                
            elif data_dims == '2d_spectral':
                # (channels, frequencies) - нет временной динамики
                channel_data = power_data[channel, :]
                band_power = np.mean(channel_data[band_mask])
                
            else:
                band_power = np.nan
                
            band_powers[period_name] = band_power
            
        except Exception as e:
            print(f"    Error processing {period_name}: {e}")
            band_powers[period_name] = np.nan
    
    return band_powers

def perform_frequency_specific_analysis(raw_df, significant_results, freqs, results_arr):
    """Выполняет анализ для отдельных частот и окон 2-3 Hz для значимых результатов"""
    print(f"\nPerforming frequency-specific analysis for {len(significant_results)} significant results...")
    
    frequency_results = []
    
    for idx, sig_result in enumerate(significant_results):
        period_type = sig_result['period_type']
        channel = sig_result['channel']
        freq_band = sig_result['frequency_band']
        
        print(f"  Processing significant result {idx+1}/{len(significant_results)}: {period_type}, channel {channel}, {freq_band}")
        
        # Фильтруем данные для этого конкретного случая
        subset_data = raw_df[
            (raw_df['period_type'] == period_type) &
            (raw_df['channel'] == channel) &
            (raw_df['frequency_band'] == freq_band)
        ]
        
        if len(subset_data) == 0:
            continue
            
        # Получаем subject_id и time_category для анализа
        subject_ids = subset_data['subject_id'].unique()
        
        for subject_id in subject_ids[:5]:  # Ограничим для скорости
            subject_data = subset_data[subset_data['subject_id'] == subject_id]
            if len(subject_data) == 0:
                continue
                
            time_category = subject_data['time_category'].iloc[0]
            
            # Находим соответствующие исходные FFT данные
            for record in results_arr:
                power_data, s_id, t_id, gender, handiness, age, label, img, task_type = record
                if s_id != subject_id:
                    continue
                
                # Определяем структуру данных
                if power_data.ndim == 3:
                    data_dims = '3d'
                elif power_data.ndim == 2:
                    if power_data.shape[0] == 64 or power_data.shape[0] == 63:
                        data_dims = '2d_spectral'
                    else:
                        data_dims = '2d_temporal'
                else:
                    continue
                
                # Анализ для отдельных частот в диапазоне 2-3 Hz
                freq_mask_2_3 = (freqs >= 2) & (freqs < 3)
                target_freqs = freqs[freq_mask_2_3]
                freq_indices = np.where(freq_mask_2_3)[0]
                
                for freq_idx, freq in zip(freq_indices[:3], target_freqs[:3]):  # Первые 3 частоты
                    try:
                        if data_dims == '3d':
                            # Для 3D данных используем весь временной период
                            real_power = np.mean(power_data[channel, :, freq_idx])
                            
                        elif data_dims == '2d_temporal':
                            real_power = np.mean(power_data[:, freq_idx])
                            
                        elif data_dims == '2d_spectral':
                            real_power = power_data[channel, freq_idx]
                        
                        frequency_results.append({
                            'original_comparison_idx': idx,
                            'period_type': period_type,
                            'channel': channel,
                            'original_frequency_band': freq_band,
                            'specific_frequency': freq,
                            'subject_id': subject_id,
                            'time_category': time_category,
                            'real_power': real_power,
                            'data_dimensionality': data_dims
                        })
                        
                    except Exception as e:
                        continue
        
        if (idx + 1) % 10 == 0:
            print(f"  Processed {idx + 1}/{len(significant_results)} significant results")
    
    return pd.DataFrame(frequency_results)

# %% [markdown]
# # Load data

# %%
print("Loading data...")
loaded = np.load('C:/Users/HP/Documents/GitHub/EEG-Image-Reconstruction/Generated/Spectrums/exec_and_rest_fft.npz')

# Создаем список для хранения всех данных
results_arr = []

print("Reading records from npz file...")
i = 0
while f'power_{i}' in loaded:
    power = loaded[f'power_{i}']
    s_id = int(loaded[f'subject_id_{i}'])
    t_id = int(loaded[f'trial_id_{i}'])
    gender = str(loaded[f'gender_{i}'])
    handiness = str(loaded[f'handiness_{i}'])
    age = int(loaded[f'age_{i}'])
    label = int(loaded[f'label_{i}'])
    img = loaded[f'img_{i}']
    task_type = str(loaded[f'task_type_{i}'])
    
    results_arr.append([power, s_id, t_id, gender, handiness, age, label, img, task_type])
    i += 1

print(f"Loaded {len(results_arr)} records")

# Анализируем структуру power данных
freqs, n_channels, n_freq_bins = analyze_fft_structure(loaded)
print(f"Frequency range: {freqs[0]:.1f} - {freqs[-1]:.1f} Hz")

# Загружаем временные категории
print("Loading time categories...")
time_categories = process_excel_time('C:/Users/HP/Documents/GitHub/EEG-Image-Reconstruction/Supplementary/Experiment_Metadata.xlsx', column_index=19)

# Определяем частотные диапазоны EEG
freq_bands = {
    'delta': (0, 4),
    'theta': (4, 8),
    'alpha': (8, 13),
    'beta': (13, 30),
    'gamma': (30, 80)
}

# Создаем список для результатов
results = []
# Out:
# Loading data...
# Reading records from npz file...
# Loaded 651 records
# Shape of power data: (63, 381)
# Number of dimensions: 2
# Data structure: (channels, frequencies)
# Number of channels: 63
# Number of frequency bins: 381
# Frequency range: 0.0 - 100.0 Hz
# Loading time categories...

# %% [markdown]
# # Processing of all records

# %%
print(f"\nProcessing {len(results_arr)} power records...")

for i, record in enumerate(results_arr):
    try:
        power_data, s_id, t_id, gender, handiness, age, label, img, task_type = record
        
        if s_id - 1 >= len(time_categories) or time_categories[s_id - 1] is None:
            print(f"Record {i}: No time category for subject {s_id}")
            continue
        
        time_cat = time_categories[s_id - 1]
        
        print(f"Record {i}: subject {s_id}, shape {power_data.shape}, ndim {power_data.ndim}")
        
        # Определяем структуру данных
        if power_data.ndim == 3:
            data_dims = '3d'
            n_channels_current = power_data.shape[0]
        elif power_data.ndim == 2:
            if power_data.shape[0] == 64 or power_data.shape[0] == 63:
                data_dims = '2d_spectral'
                n_channels_current = power_data.shape[0]
            else:
                data_dims = '2d_temporal'
                n_channels_current = 1
        else:
            print(f"  Unsupported dimensionality: {power_data.ndim}")
            continue
        
        # Извлекаем периоды с учетом структуры данных
        periods = extract_exec_rest_periods(power_data, data_dims)
        
        # Обрабатываем каждый канал и частотный диапазон
        for channel in range(n_channels_current):
            for band_name, (f_low, f_high) in freq_bands.items():
                band_mask = (freqs >= f_low) & (freqs < f_high)
                
                # Получаем мощности для всех периодов
                band_powers = process_power_data(
                    power_data, periods, channel, band_mask, data_dims
                )
                
                # Сохраняем результаты для каждого периода
                for period_name, band_power in band_powers.items():
                    if not np.isnan(band_power):
                        results.append({
                            'subject_id': s_id,
                            'trial_id': t_id,
                            'time_category': time_cat,
                            'period_type': period_name,
                            'channel': channel,
                            'frequency_band': band_name,
                            'power': band_power,
                            'gender': gender,
                            'handiness': handiness,
                            'age': age,
                            'label': label,
                            'task_type': task_type,
                            'data_dimensionality': data_dims
                        })
        
        if (i + 1) % 10 == 0:
            print(f"Processed {i + 1}/{len(results_arr)} records")
            
    except Exception as e:
        print(f"Error processing record {i}: {e}")
        continue

print("Power data collection completed!")
print(f"Collected {len(results)} data points")
# Out:
# Processing 651 power records...
# Record 0: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 1: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 2: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 3: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 4: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 5: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 6: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 7: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 8: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 9: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 10/651 records
# Record 10: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 11: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 12: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 13: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 14: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 15: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 16: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 17: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 18: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 19: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 20/651 records
# Record 20: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 21: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 22: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 23: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 24: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 25: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 26: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 27: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 28: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 29: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 30/651 records
# Record 30: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 31: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 32: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 33: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 34: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 35: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 36: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 37: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 38: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 39: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 40/651 records
# Record 40: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 41: subject 4, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 42: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 43: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 44: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 45: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 46: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 47: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 48: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 49: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 50/651 records
# Record 50: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 51: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 52: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 53: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 54: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 55: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 56: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 57: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 58: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 59: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 60/651 records
# Record 60: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 61: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 62: subject 14, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 63: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 64: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 65: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 66: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 67: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 68: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 69: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 70/651 records
# Record 70: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 71: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 72: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 73: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 74: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 75: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 76: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 77: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 78: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 79: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 80/651 records
# Record 80: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 81: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 82: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 83: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 84: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 85: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 86: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 87: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 88: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 89: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 90/651 records
# Record 90: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 91: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 92: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 93: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 94: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 95: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 96: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 97: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 98: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 99: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 100/651 records
# Record 100: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 101: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 102: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 103: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 104: subject 15, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 105: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 106: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 107: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 108: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 109: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 110/651 records
# Record 110: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 111: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 112: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 113: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 114: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 115: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 116: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 117: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 118: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 119: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 120/651 records
# Record 120: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 121: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 122: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 123: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 124: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 125: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 126: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 127: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 128: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 129: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 130/651 records
# Record 130: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 131: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 132: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 133: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 134: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 135: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 136: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 137: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 138: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 139: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 140/651 records
# Record 140: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 141: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 142: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 143: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 144: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 145: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 146: subject 1, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 147: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 148: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 149: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 150/651 records
# Record 150: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 151: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 152: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 153: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 154: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 155: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 156: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 157: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 158: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 159: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 160/651 records
# Record 160: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 161: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 162: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 163: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 164: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 165: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 166: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 167: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 168: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 169: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 170/651 records
# Record 170: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 171: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 172: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 173: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 174: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 175: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 176: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 177: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 178: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 179: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 180/651 records
# Record 180: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 181: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 182: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 183: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 184: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 185: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 186: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 187: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 188: subject 5, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 189: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 190/651 records
# Record 190: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 191: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 192: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 193: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 194: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 195: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 196: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 197: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 198: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 199: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 200/651 records
# Record 200: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 201: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 202: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 203: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 204: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 205: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 206: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 207: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 208: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 209: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 210/651 records
# Record 210: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 211: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 212: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 213: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 214: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 215: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 216: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 217: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 218: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 219: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 220/651 records
# Record 220: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 221: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 222: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 223: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 224: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 225: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 226: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 227: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 228: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 229: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 230/651 records
# Record 230: subject 3, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 231: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 232: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 233: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 234: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 235: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 236: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 237: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 238: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 239: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 240/651 records
# Record 240: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 241: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 242: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 243: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 244: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 245: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 246: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 247: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 248: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 249: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 250/651 records
# Record 250: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 251: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 252: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 253: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 254: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 255: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 256: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 257: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 258: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 259: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 260/651 records
# Record 260: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 261: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 262: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 263: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 264: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 265: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 266: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 267: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 268: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 269: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 270/651 records
# Record 270: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 271: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 272: subject 2, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 273: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 274: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 275: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 276: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 277: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 278: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 279: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 280/651 records
# Record 280: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 281: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 282: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 283: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 284: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 285: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 286: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 287: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 288: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 289: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 290/651 records
# Record 290: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 291: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 292: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 293: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 294: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 295: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 296: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 297: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 298: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 299: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 300/651 records
# Record 300: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 301: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 302: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 303: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 304: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 305: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 306: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 307: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 308: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 309: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 310/651 records
# Record 310: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 311: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 312: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 313: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 314: subject 7, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 315: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 316: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 317: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 318: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 319: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 320/651 records
# Record 320: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 321: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 322: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 323: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 324: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 325: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 326: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 327: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 328: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 329: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 330/651 records
# Record 330: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 331: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 332: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 333: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 334: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 335: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 336: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 337: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 338: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 339: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 340/651 records
# Record 340: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 341: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 342: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 343: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 344: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 345: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 346: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 347: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 348: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 349: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 350/651 records
# Record 350: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 351: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 352: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 353: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 354: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 355: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 356: subject 10, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 357: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 358: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 359: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 360/651 records
# Record 360: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 361: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 362: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 363: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 364: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 365: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 366: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 367: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 368: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 369: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 370/651 records
# Record 370: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 371: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 372: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 373: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 374: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 375: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 376: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 377: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 378: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 379: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 380/651 records
# Record 380: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 381: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 382: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 383: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 384: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 385: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 386: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 387: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 388: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 389: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 390/651 records
# Record 390: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 391: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 392: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 393: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 394: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 395: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 396: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 397: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 398: subject 8, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 399: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 400/651 records
# Record 400: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 401: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 402: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 403: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 404: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 405: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 406: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 407: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 408: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 409: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 410/651 records
# Record 410: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 411: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 412: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 413: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 414: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 415: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 416: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 417: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 418: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 419: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 420/651 records
# Record 420: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 421: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 422: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 423: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 424: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 425: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 426: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 427: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 428: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 429: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 430/651 records
# Record 430: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 431: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 432: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 433: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 434: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 435: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 436: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 437: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 438: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 439: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 440/651 records
# Record 440: subject 12, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 441: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 442: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 443: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 444: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 445: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 446: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 447: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 448: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 449: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 450/651 records
# Record 450: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 451: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 452: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 453: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 454: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 455: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 456: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 457: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 458: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 459: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 460/651 records
# Record 460: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 461: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 462: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 463: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 464: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 465: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 466: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 467: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 468: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 469: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 470/651 records
# Record 470: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 471: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 472: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 473: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 474: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 475: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 476: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 477: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 478: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 479: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 480/651 records
# Record 480: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 481: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 482: subject 16, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 483: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 484: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 485: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 486: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 487: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 488: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 489: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 490/651 records
# Record 490: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 491: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 492: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 493: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 494: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 495: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 496: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 497: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 498: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 499: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 500/651 records
# Record 500: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 501: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 502: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 503: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 504: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 505: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 506: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 507: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 508: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 509: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 510/651 records
# Record 510: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 511: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 512: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 513: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 514: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 515: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 516: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 517: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 518: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 519: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 520/651 records
# Record 520: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 521: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 522: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 523: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 524: subject 11, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 525: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 526: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 527: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 528: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 529: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 530/651 records
# Record 530: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 531: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 532: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 533: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 534: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 535: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 536: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 537: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 538: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 539: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 540/651 records
# Record 540: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 541: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 542: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 543: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 544: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 545: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 546: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 547: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 548: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 549: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 550/651 records
# Record 550: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 551: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 552: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 553: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 554: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 555: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 556: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 557: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 558: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 559: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 560/651 records
# Record 560: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 561: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 562: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 563: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 564: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 565: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 566: subject 9, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 567: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 568: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 569: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 570/651 records
# Record 570: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 571: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 572: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 573: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 574: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 575: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 576: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 577: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 578: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 579: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 580/651 records
# Record 580: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 581: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 582: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 583: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 584: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 585: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 586: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 587: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 588: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 589: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 590/651 records
# Record 590: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 591: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 592: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 593: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 594: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 595: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 596: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 597: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 598: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 599: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 600/651 records
# Record 600: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 601: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 602: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 603: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 604: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 605: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 606: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 607: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 608: subject 13, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 609: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 610/651 records
# Record 610: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 611: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 612: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 613: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 614: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 615: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 616: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 617: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 618: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 619: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 620/651 records
# Record 620: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 621: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 622: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 623: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 624: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 625: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 626: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 627: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 628: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 629: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 630/651 records
# Record 630: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 631: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 632: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 633: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 634: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 635: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 636: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 637: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 638: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 639: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 640/651 records
# Record 640: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 641: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 642: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 643: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 644: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 645: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 646: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 647: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 648: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Record 649: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Processed 650/651 records
# Record 650: subject 6, shape (63, 381), ndim 2
#   Extracted periods: ['full']
# Power data collection completed!
# Collected 205065 data points

# %% [markdown]
# # Statistical analysis

# %%
# Проверяем, есть ли данные для анализа
if len(results) == 0:
    print("No data collected! Check your data structure.")
else:
    # Создаем DataFrame с сырыми данными
    raw_df = pd.DataFrame(results)
    
    # Проверяем распределение данных
    print("\nData distribution:")
    print(f"Total records: {len(raw_df)}")
    print(f"Day records: {len(raw_df[raw_df['time_category'] == 'day'])}")
    print(f"Evening records: {len(raw_df[raw_df['time_category'] == 'evening'])}")
    print(f"Period types distribution:")
    period_counts = raw_df['period_type'].value_counts()
    for period, count in period_counts.items():
        day_count = len(raw_df[(raw_df['period_type'] == period) & (raw_df['time_category'] == 'day')])
        evening_count = len(raw_df[(raw_df['period_type'] == period) & (raw_df['time_category'] == 'evening')])
        print(f"  {period}: {count} total ({day_count} day, {evening_count} evening)")
    
    # Статистический анализ: сравнение day vs evening для КАЖДОГО периода
    statistical_results = []
    
    print(f"\nPerforming statistical analysis for ALL period types...")
    
    # АНАЛИЗ ДЛЯ КАЖДОГО ПЕРИОДА ОТДЕЛЬНО: day vs evening
    available_periods = raw_df['period_type'].unique()
    print(f"Available period types for analysis: {available_periods}")
    
    for period in available_periods:
        period_data = raw_df[raw_df['period_type'] == period]
        grouping_columns = ['channel', 'frequency_band']
        
        print(f"\nAnalyzing {period} period (day vs evening):")
        print(f"  Total records: {len(period_data)}")
        print(f"  Day records: {len(period_data[period_data['time_category'] == 'day'])}")
        print(f"  Evening records: {len(period_data[period_data['time_category'] == 'evening'])}")
        
        comparisons_count = 0
        for (channel, band), group in period_data.groupby(grouping_columns):
            day_data = group[group['time_category'] == 'day']['power']
            evening_data = group[group['time_category'] == 'evening']['power']
            
            if len(day_data) >= 3 and len(evening_data) >= 3:
                try:
                    # Используем t-test или Mann-Whitney
                    try:
                        stat, p_value = stats.ttest_ind(day_data, evening_data)
                        test_name = "t-test"
                    except:
                        stat, p_value = stats.mannwhitneyu(day_data, evening_data)
                        test_name = "mannwhitneyu"
                    
                    significant = p_value < 0.05
                    
                    statistical_results.append({
                        'comparison': f'day_vs_evening',
                        'period_type': period,
                        'channel': channel,
                        'frequency_band': band,
                        'test_name': test_name,
                        'statistic': stat,
                        'p_value': p_value,  # Сохраняем чистое p-value
                        'significant': significant,
                        'n_day': len(day_data),
                        'n_evening': len(evening_data),
                        'mean_power_day': np.mean(day_data),
                        'mean_power_evening': np.mean(evening_data),
                        'power_difference': np.mean(day_data) - np.mean(evening_data)
                    })
                    comparisons_count += 1
                    
                except Exception as e:
                    continue
        
        print(f"  Completed {comparisons_count} comparisons for {period}")
    
    # АНАЛИЗ ДЛЯ ОБЪЕДИНЕННЫХ REST ПЕРИОДОВ
    if 'rest1' in available_periods and 'rest2' in available_periods:
        print(f"\nAnalyzing combined rest periods (day vs evening):")
        
        rest_combined_df = raw_df.copy()
        rest_combined_df['period_type_combined'] = rest_combined_df['period_type'].apply(
            lambda x: 'rest_combined' if x in ['rest1', 'rest2'] else x
        )
        
        rest_combined_data = rest_combined_df[rest_combined_df['period_type_combined'] == 'rest_combined']
        grouping_columns = ['channel', 'frequency_band']
        
        comparisons_count = 0
        for (channel, band), group in rest_combined_data.groupby(grouping_columns):
            day_data = group[group['time_category'] == 'day']['power']
            evening_data = group[group['time_category'] == 'evening']['power']
            
            if len(day_data) >= 3 and len(evening_data) >= 3:
                try:
                    # Используем t-test или Mann-Whitney
                    try:
                        stat, p_value = stats.ttest_ind(day_data, evening_data)
                        test_name = "t-test"
                    except:
                        stat, p_value = stats.mannwhitneyu(day_data, evening_data)
                        test_name = "mannwhitneyu"
                    
                    significant = p_value < 0.05
                    
                    statistical_results.append({
                        'comparison': 'day_vs_evening',
                        'period_type': 'rest_combined',
                        'channel': channel,
                        'frequency_band': band,
                        'test_name': test_name,
                        'statistic': stat,
                        'p_value': p_value,
                        'significant': significant,
                        'n_day': len(day_data),
                        'n_evening': len(evening_data),
                        'mean_power_day': np.mean(day_data),
                        'mean_power_evening': np.mean(evening_data),
                        'power_difference': np.mean(day_data) - np.mean(evening_data)
                    })
                    comparisons_count += 1
                    
                except Exception as e:
                    continue
        
        print(f"  Completed {comparisons_count} comparisons for rest_combined")
    
    # Создаем финальный DataFrame
    if statistical_results:
        final_df = pd.DataFrame(statistical_results)
        
        # НЕ ИСПРАВЛЯЕМ данные анализа - оставляем чистые p-value
        n_comparisons = len(final_df)
        if n_comparisons > 0:
            final_df['p_value_corrected'] = final_df['p_value'] * n_comparisons
            final_df['p_value_corrected'] = np.minimum(final_df['p_value_corrected'], 1.0)
            final_df['significant_corrected'] = final_df['p_value_corrected'] < 0.05
            
            # Сохраняем результаты с чистыми p-value
            output_path = 'C:/Users/HP/Documents/GitHub/EEG-Image-Reconstruction/Supplementary/daytime_fft.csv'
            final_df.to_csv(output_path, index=False)
            
            print(f"\nAnalysis completed! Results saved to {output_path}")
            print(f"Total comparisons: {len(final_df)}")
            print(f"Significant results (uncorrected p < 0.05): {final_df['significant'].sum()}")
            print(f"Significant results (corrected p < 0.05): {final_df['significant_corrected'].sum()}")
            
            # Детальная сводка по периодам
            print("\nResults by period type:")
            all_periods_in_results = final_df['period_type'].unique()
            for period in all_periods_in_results:
                period_data = final_df[final_df['period_type'] == period]
                if len(period_data) > 0:
                    sig_uncorrected = period_data['significant'].sum()
                    sig_corrected = period_data['significant_corrected'].sum()
                    print(f"  {period}: {len(period_data)} comparisons, {sig_uncorrected} uncorrected significant, {sig_corrected} corrected significant")
            
            # # Анализ для значимых результатов на отдельных частотах 2-3 Hz
            # significant_results_list = final_df[final_df['significant'] == True].to_dict('records')
            # if len(significant_results_list) > 0:
            #     print(f"\nPerforming detailed frequency analysis for {len(significant_results_list)} significant results...")
            #     frequency_specific_df = perform_frequency_specific_analysis(
            #         raw_df, significant_results_list, freqs, results_arr
            #     )
                
            #     if len(frequency_specific_df) > 0:
            #         freq_output_path = 'C:/Users/HP/Documents/GitHub/EEG-Image-Reconstruction/Supplementary/frequency_specific_analysis_2_3Hz.csv'
            #         frequency_specific_df.to_csv(freq_output_path, index=False)
            #         print(f"Frequency-specific analysis saved to {freq_output_path}")
            #         print(f"Analyzed {len(frequency_specific_df)} frequency-specific data points")
            
            # print("\nFirst 10 results (with all period types):")
            # print(final_df.head(10).to_string())
            
            # # Показываем распределение по всем периодам
            # print(f"\nFinal results include ALL period types: {list(final_df['period_type'].unique())}")
        else:
            print("No statistical results were generated.")
    else:
        print("No statistical results were generated.")

print("\nScript execution completed successfully!")
# Out:
# Data distribution:
# Total records: 205065
# Day records: 112455
# Evening records: 92610
# Period types distribution:
#   full: 205065 total (112455 day, 92610 evening)
#
# Performing statistical analysis for ALL period types...
# Available period types for analysis: ['full']
#
# Analyzing full period (day vs evening):
#   Total records: 205065
#   Day records: 112455
#   Evening records: 92610
#   Completed 315 comparisons for full
#
# Analysis completed! Results saved to C:/Users/HP/Documents/GitHub/EEG-Image-Reconstruction/Supplementary/daytime_fft.csv
# Total comparisons: 315
# Significant results (uncorrected p < 0.05): 246
# Significant results (corrected p < 0.05): 158
#
# Results by period type:
#   full: 315 comparisons, 246 uncorrected significant, 158 corrected significant
#
# Script execution completed successfully!
